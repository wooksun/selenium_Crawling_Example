# %%
import warnings
warnings.filterwarnings("ignore")
from IPython.display import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams["font.size"] = 10
plt.rcParams["font.family"] = 'NanumGothicCoding'
plt.rcParams['font.size']=15
import seaborn as sns

# %%
from wordcloud import WordCloud
from PIL import Image
from wordcloud import STOPWORDS
import nltk
from konlpy.tag import Twitter
t = Twitter()

# %%
# 네이버 웹툰 리뷰가 저장된 파일 전체를 한번에 읽는다.
review = open('./review.txt', encoding='utf-8').read()
review
# Out:
# '비상금 주식 때려넣고 맘고생하기\n맘고생하면,,, 스트레스로 빠지긴 빠짐ㅋ\n남편이랑 3개월 끊어놓고 한번도 안감ㅋㅋㅋㅋㅋㅋ\n술끊고, 야식 끊고, 라면 끊고 간식 끊고 밥 반공기로 줄이고 삼시 세끼 꼬박꼬박 챙겨먹으면서 2년동안 앞자리수 두 번 바꿨는데요. 지금은 술도 가끔 마시고 먹고 싶은 거도 먹고 삼시 세끼 꼬박 챙겨먹는 건 아니지만 유지하려고 노력중입니당. 그래도 야식 안 먹어용, 평생하는 거라 생각하시는 게 젤 좋아여...또르르내일부터 하자고 생각하면 망하는 지름길임다ㅠㅠ \nㅋㅋㅋ\n튀김에 있는 탄수화물은요...?\n적당히 해요 ㅋㅋㅋㅋㅋㅋㅋ\n킹장갓시경\n현실: 1컷\n???: 물만 먹었는데....(무엇을 물처럼 먹어 치웠는지 생각해 보시오.)\n나쁜놈이네,,, 신랑이 저렇게 빼면 신부가 묻힌다규ㅠㅠㅠ\n살어떻게 빼요? 청첩장 나눠주면서 술먹으면 찌던데ㅜ \n너 C야 T발?\n냥군 진짜 대단한 사람이네요 의지도 대단하고..\n운동 안해도 3키로 저절로 빠지던데ㅋㅋ\n맞아요 다이어트 성공한 사람들은 대단한 것 같네요👍\nㅋㅋㅋㅋㅋ 표정 무엇?🤣\n우선 그 과자부터 내려놓고 말하시죠?ㅋㅋㅋㅋ 🤣\n냥군....멸치가 다 됐어....🤣ㅋㅋㅋ\n표정 너무 웃긴거 아니냐고🤣\n엄마:앗싸!~~\n저는 예식당일 너무나도 부지런한 엄빠덕분에 식장에 일직도착해서 1층애 있던 햄버거집에서 햄버거 세트 야무지게 먹고 결혼식을 치뤘?는데 그날 .. 임신해서 결혼했냐는 후문을 참 많이 들었지요.. 그나마 햄버거막었단 핑계가 있어서 다행 원래도 복부비만인디요 팔다리가 얇아 숨겨왔던 ㅋㅋㅋㅋ \n마루야 ..\n날잡고 결혼식날까지 6킬로가량 뺐어요 그럼뭐해 결혼하고 1년만에 도로 다 쪘는데....\n맞아 지금 재수중인데 6월에 시간의 촉박함을 느끼고 아점저먹는시간을 전부 공부시간으로 바꿨더니 이때 8월에는 15키로 빠져있었음 (두달 내내 굶은거 아님)(7월부턴 다시 잘 먹기 시작했는데 양이 줄어서 그럼)\n저도 이지은,신지니 다해봤지만 결국 덤벨들고 중량하는게 진짜 효과직빵이더라구요!\n살찌면 투뿔되는건 틀린 얘긴 아니긴..하죠 ㅜ\n아 배고파\n저희 아버지도 뚱뚱하셨는ㄷ지긍은 다이어트 하셔서\n날씬해짐\n체중계 "우와" ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ\n샹크스 다이어트법팔을 자르면 몸무게가 수 kg 가벼워진다\n\n플로지스톤 다이어트법\n죽으면 2g정도 가벼워진다고 했던거 같다\n우와Kg 이시구나•••!!!!!\n네 저는 1년간 최고 몸무게로 식에 올라갔답니다 핳핳핳\n헐 \n이게 이렇다니까요...? ㅋㅋㅋㅋㅋ\n지금의 나.. d-21 ㅜㅜ\n쭈그렁 한거보소\n난 이제 앞자리가 1로 고정인데....\n아 빵터짐 ㅋ\n우와 제 프사가 여기 있었네요...!!\n나의 시험을 바라보는 표정\n냥군이뺀거 자까님한테갓네ㅋㅋ\n성공했다가 요요...\n치킨은 밀가루..\n결혼 전 3개월 운동해서 10키로 근손실 없이 빼고 20키로 요요 왔어요 요요요요요지경세상\nINTJ 같음\n지방분해주사 + 승모근보톡스\n뼈 때리네ㅠㅠ\n결혼식 바로 전날 신랑이랑 친구들이랑 호프집에서 신나게 술먹다가 친척한테 걸렸어요 ㅋㅋㅋ 하 벌써 10년전이네요..^^\n고3때 한창 수능공부할때 스트레스 받기도하고 급 다이어트 삘이 꽂혀서 공부하면서 12키로 넘게 뺌 물론 1년넘게 유지중 ㅎㅎ 진짜 초절식하면서 뺐네여\n자까님 결국 다이어트 성공햇다는 말은 없는거냐구요ㅋㅋㅋ 연출상으로도 이건 했다~ 이만큼은 성공했다~같은 말이 단 한마디도 없네ㅋㅋㅋㅋ\n와.. 진짜 결혼하기 전 내모습이랑 똑같아서 소름돋았어요\n있어요 저 3개월에 20kg 뺐는데 파인애플+요거트 최고조합이었죠. 산성분이 들어 지방 분해해주는 레몬 파인애플같은 과일과 장운동 활발히 시켜 내장지방 빼주는 요거트의 조합은 효과 빠르죠\n땡볕에 농구하면 살 금방빠짐...근데 까매짐\n에어팟 현실반영 제대로네ㅋㅋ\n뱃살을 얻으면 세상 너그러워짐내가 초 예민한 사람인 줄 알았는데 살쪄보니 너그러워짐\n49>43 일주일만에 빼봤는데1.5km 매일 뛰다가 걷고 하루에 1000kcal미만으로 먹음\n근데 너무 보기 안좋아서 46으로 찌우고 유지하다가\n지금은 48이네요....ㄸㄹㄹ 잘먹고 건강한게 최고인듯해요\n제동생도 미술입시할때 60키로꺼지 쪘다가 대학1학년되고 야작하고 과제에 치여거 48키로까지 빠졌읍니다..대학가서 빠진단게 사실이었음\n자까님 커엽다\n중3때 이후로 12년간 몸무게 앞자리 변화 없이 대체로 유지 중이에요 중간에 찌고 빠지고는 있지만 앞자리 수가 줄면 줄었지 절대 늘진않더라구요 \n8. 운동은 처음에는 기초체력을 기르기 위해 걷기나 유산소 운동부터 시작해서 ( 저질체력이래도 5분~10분짜리부터 차차 시작하면 됨. ) 차차 늘려나가면 됨. 단 익숙해질 때마다 강도를 서서히 올려야 함.워밍업( 동적 스트레칭)- 무산소 운동- 유산소 운동- 정적 스트레칭 \n9. 폭식했다 해도 망했다면서 포기하지 말길. 며칠간 유산소 운동 강도 늘려서 하고 식이요법 병행하면 됨.\n10. 생리증후군 때 폭식하는 습관 끊어야 함. 그리고 생리 기간에는 가벼운 운동이나 요가 정도만 하던지 푹 쉬어야 하고 생리가 불규칙적이면 똑같이 운동해도 안 빠짐.\n11. 굶지마라. 두 번 말한다. 굶지 마라. 굶으면 몸이 비상사태 모드로 지방을 축적해서 결과적으로 전보다 더 살이 찜.\n12. 아침도 가볍게라도 챙겨먹는 게 나음. 13. 술 좋아하면 술도 자제하길. 복부비만의 원인이 됨.\n\n이렇게 해서 80kg 가까이 나갔다가 지금 61~63 유지 중( 정체지 ) 이다.\n3. 가급적 날짜가 바뀌기 전에 자고 7~8시간씩 자기. (10시쯤 자면 금상첨화임. ) 4. 저녁은 잠들기 4시간 전에 먹기. 5. 일반식은 밥  2/3 공기 or 반 공기 + 짠 반찬은 조금만 + 국물은 건더기만 약간 건져서 6. 당 함량이 높은 음식, 기름진 음식, 짠 음식은 적게 먹거나 가급적 안 먹기. ( 치팅데이의 경우 두 달 후 주 1회씩 가졌음. ) 7. 외식할 경우 김밥, 비빔밥, 샐러드, 샐러드 파스타, 서브웨이 샌드위치, 샤브샤브 ( 소고기 150g +야채위주 ) , 쌀국수, (  본죽 비빔밥 추천함.)\n졸업하고 두 달 지나서 다이어트 시작했음. 다이어트는 생활습관을 바꾸고 더 나아가 평생 동안 지속할 수 있는지를 고려해서 식이요법과 운동을 병행해야 함. 물론 고도비만의 경우 처음부터 운동을 하면 관절이 상하기 때문에 식이요법만 해서 지방을 덜어내는 게 좋음. 1. 밥 먹고 바로 눕지 말고 2~3시간 후에 눕기. ( 4시간 후에 눕거나 안 누우면 더 좋음. ) 2. 세 끼 식사 외에 간식, 야식은 금지. 정 먹고 싶으면 아메리카노, 차, 저지방 우유, 블루베리, 딸기, 채소 중 하나로 대체. 배고프면 물 중간중간 마시기. ( 물은 매일 최소 1리터에서 최대 2리터씩 마셔야 함. 나 같은 경우는 1.5리터씩 마셔줌. )\n과제...\n입이 대빵만큼 나왔는데요?\n와 저 지금 안성탕면 부셔먹으면서 보는데 깜놀 ㅋㅋㅋㅋㅋㅋㅋ\n청첩장 돌리고 인사하고 매일같이 약속 잡으니까 살이 저절로 빠졌음..\n개아련해 ㅋㅋ\nㅋㅋㅋㅋㅋ티답변 너무 웃겨\n근데 운동진짜 안한사람들은 그럴체력조차없기에 조깅부터 하는거 추천...지짜 건강도 있을때 챙기는거고 운동도 할 체력이있을때부터 해야함\n\n\n\n(침대에서 뒹굴거리며...\n체중계 우와 ㅋㅋ\n그래서 앞컷엔 실제로 한 말을 붙인거군\n장염다이어트\n167cm 현 대3인데 고3때 코로나 시작이였어서 62kg찍었다가 대1때 가족들이랑 걷고 식단해서 54kg까지 빼고 다시 쪄서 58kg 되었다가 대2 여름에 대면 풀리고 헬스장 다니면서 55kg까지 뺏다가 현재는 다시 59kg 으로 돌아오니 발목이 원래 약한데 발목이 점점 아파져서 강의로 생활체육1도 들으면서 운동하기로 했고 생활관 사니깐 학교 체단실 가서 운동도 할 예정\n나도안다고...\n고1이 되기까지 몸무게 50넘은적업ㅂ슴...\n특정부위 살빼는 운동은 없습니다.. 림프절을 폼롤러로 조지라는분들 림프절 조지는게 지방빼는거랑 무슨관련이 있나요..  아예 가슴빠질 각오하고 유산소 하루 3시간씩 조지던가, 아님 지방흡입 하는게 제일 좋습니다.\nㅌㅊ ,ㅌ\n두달 동안 70에서 4 ...

# %%
# 한글 형태소 분석을 실행한다.
review_tokens = t.nouns(review)
review_tokens
# Out:
# ['비상',
#  '금',
#  '주식',
#  '맘',
#  '고생',
#  '맘',
#  '고생',
#  '스트레스',
#  '남편',
#  '개월',
#  '한번',
#  '안감',
#  '술',
#  '야식',
#  '라면',
#  '간식',
#  '밥',
#  '공기',
#  '줄',
#  '삼시',
#  '끼',
#  '꼬박꼬박',
#  '앞',
#  '두',
#  '번',
#  '지금',
#  '술',
#  '가끔',
#  '거도',
#  '삼시',
#  '끼',
#  '꼬박',
#  '건',
#  '유지',
#  '노력',
#  '야식',
#  '안',
#  '평생',
#  '거',
#  '생각',
#  '게',
#  '젤',
#  '또르르',
#  '내일',
#  '하자',
#  '생각',
#  '지름길',
#  '튀김',
#  '탄수화물',
#  '요',
#  '해',
#  '킹',
#  '시경',
#  '현실',
#  '컷',
#  '물',
#  '무엇',
#  '물',
#  '생각',
#  '놈',
#  '신랑',
#  '신부',
#  '규',
#  '살',
#  '빼',
#  '청첩장',
#  '술',
#  '너',
#  '발',
#  '냥',
#  '진짜',
#  '사람',
#  '요',
#  '의지',
#  '운동',
#  '안해',
#  '저절로',
#  '다이어트',
#  '사람',
#  '것',
#  '표정',
#  '무엇',
#  '우선',
#  '그',
#  '과자',
#  '말',
#  '냥',
#  '멸치',
#  '표정',
#  '엄마',
#  '앗',
#  '저',
#  '예식',
#  '당일',
#  '엄빠',
#  '덕분',
#  '식장',
#  '직도',
#  '층애',
#  '햄버거',
#  '집',
#  '햄버거',
#  '세트',
#  '결혼식',
#  '그날',
#  '임신',
#  '결혼',
#  '후문',
#  '햄버거',
#  '핑계',
#  '다행',
#  '원래',
#  '복부비만',
#  '디',
#  '팔다리',
#  '마루',
#  '날',
#  '잡고',
#  '결혼식',
#  '날',
#  '킬로',
#  '가량',
#  '뭐해',
#  '결혼',
#  '도로',
#  '지금',
#  '재수',
#  '시간',
#  '점저',
#  '시간',
#  '전부',
#  '부시',
#  '때',
#  '달',
#  '내내',
#  '다시',
#  '먹기',
#  '시작',
#  '양',
#  '저',
#  '이지은',
#  '신지',
#  '다해',
#  '덤벨',
#  '중량',
#  '진짜',
#  '효과',
#  '직빵',
#  '투뿔',
#  '얘',
#  '저희',
#  '아버지',
#  '지긍',
#  '다이어트',
#  '짐',
#  '체중',
#  '샹크스',
#  '다이어트',
#  '법팔',
#  '몸무게',
#  '수',
#  '플로지스톤',
#  '다이어트',
#  '법',
#  '정도',
#  '시구',
#  '네',
#  '저',
#  '최고',
#  '몸무게',
#  '식',
#  '이',
#  '요',
#  '지금',
#  '나',
#  '쭈그렁',
#  '거',
#  '난',
#  '이제',
#  '앞',
#  '로',
#  '고정',
#  '제',
#  '프사',
#  '여기',
#  '나',
#  '시험',
#  '표정',
#  '냥',
#  '님',
#  '갓',
#  '요요',
#  '치킨',
#  '밀가루',
#  '결혼',
#  '전',
#  '개월',
#  '운동',
#  '손실',
#  '요요',
#  '요요',
#  '요지경',
#  '세상',
#  '지방',
#  '분해',
#  '주사',
#  '승',
#  '보톡스',
#  '뼈',
#  '결혼식',
#  '바로',
#  '전날',
#  '신랑',
#  '친구',
#  '호프',
#  '집',
#  '술',
#  '친척',
#  '벌써',
#  '고',
#  '때',
#  '한창',
#  '수능',
#  '공부',
#  '때',
#  '스트레스',
#  '기도',
#  '급',
#  '다이어트',
#  '삘',
#  '공부',
#  '유지',
#  '진짜',
#  '초',
#  '절식',
#  '여',
#  '자까님',
#  '다이어트',
#  '햇',
#  '말',
#  '구',
#  '연출',
#  '이건',
#  '이',
#  '말',
#  '단',
#  '한마디',
#  '진짜',
#  '결혼',
#  '전',
#  '모습',
#  '소름',
#  '저',
#  '개월',
#  '파인애플',
#  '요거트',
#  '최고',
#  '조합',
#  '산성',
#  '지방',
#  '분해',
#  '레몬',
#  '파인애플',
#  '과일',
#  '장',
#  '운동',
#  '내장',
#  '지방',
#  '빼주',
#  '요거트',
#  '조합',
#  '효과',
#  '땡볕',
#  '농구',
#  '살',
#  '금방',
#  '짐',
#  '에어팟',
#  '현실',
#  '반영',
#  '제대로',
#  '뱃살',
#  '세상',
#  '초',
#  '사람인',
#  '줄',
#  '짐',
#  '일주일',
#  '빼',
#  '매일',
#  '하루',
#  '미만',
#  '먹음',
#  '보기',
#  '유지',
#  '지금',
#  '최고',
#  '듯해',
#  '동생',
#  '미술',
#  '입시',
#  '때',
#  '키',
#  '대학',
#  '학년',
#  '작',
#  '과제',
#  '키로',
#  '읍니',
#  '대학가',
#  '단',
#  '자까님',
#  '커엽다',
#  '중',
#  '때',
#  '이후',
#  '몸무게',
#  '앞',
#  '변화',
#  '대체로',
#  '유지',
#  '중이',
#  '중간',
#  '찌',
#  '앞',
#  '수가',
#  '줄',
#  '절대',
#  '운동',
#  '처음',
#  '기초',
#  '체력',
#  '위해',
#  '걷기',
#  '유',
#  '산소',
#  '운동',
#  '시작',
#  '질',
#  '체력',
#  '차차',
#  '시작',
#  '차차',
#  '단',
#  '때',
#  '강도',
#  '서서히',
#  '함',
#  '워밍업',
#  '적',
#  '스트레칭',
#  '무',
#  '산소',
#  '운동',
#  '유',
#  '산소',
#  '운동',
#  '정적',
#  '스트레칭',
#  '폭',
#  '해도',
#  '포기',
#  '며칠',
#  '유',
#  '산소',
#  '운동',
#  '강도',
#  '식이요법',
#  '병행',
#  '생리',
#  '증후군',
#  '때',
#  '폭',
#  '습관',
#  '함',
#  '생리',
#  '기간',
#  '운동',
#  '요가',
#  '정도',
#  '푹',
#  '생리',
#  '불규칙',
#  '이면',
#  '운동',
#  '안',
#  '두',
#  '번',
#  '말',
#  '몸',
#  '비상',
#  '사태',
#  '모드',
#  '지방',
#  '축적',
#  '결과',
#  '전보',
#  '더',
#  '살이',
#  '찜',
#  '아침',
#  '게',
#  '술',
#  '술',
#  '자제',
#  '복부비만',
#  '원인',
#  '가까이',
#  '지금',
#  '유지',
#  '중',
#  '정체',
#  '날짜',
#  '전',
#  '자고',
#  '자기',
#  '금상첨화',
#  '임',
#  '저녁',
#  '전',
#  '먹기',
#  '일반',
#  '밥',
#  '공기',
#  '반',
#  '공기',
#  '반찬',
#  '조금',
#  '국물',
#  '건더기',
#  '약간',
#  '당',
#  '함량',
#  '음식',
#  '음식',
#  '음식',
#  '안',
#  '먹기',
#  '치팅데이',
#  '경우',
#  '두',
#  '달',
#  '후',
#  '주',
#  '외식',
#  '경우',
#  '김밥',
#  '비빔밥',
#  '샐러드',
#  '샐러드',
#  '파스타',
#  '서브웨이',
#  '샌드위치',
#  '샤브샤브',
#  '소고기',
#  '야채',
#  '위주',
#  '쌀국수',
#  '죽',
#  '비빔밥',
#  '추천',
#  '함',
#  '졸업',
#  '두',
#  '달',
#  '다이어트',
#  '시작',
#  '다이어트',
#  '생활',
#  '습관',
#  '더',
#  '평생',
#  '동안',
#  '지속',
#  '수',
#  '고려',
#  '식이요법',
#  '운동',
#  '병행',
#  '함',
#  '도비',
#  '경우',
#  '처음',
#  '운동',
#  '관절',
#  '상',
#  '때문',
#  '식이요법',
#  '지방',
#  '게',
#  '밥',
#  '바로',
#  '후',
#  '후',
#  '안',
#  '누우',
#  '더',
#  '세',
#  '끼',
#  '식사',
#  '외',
#  '간식',
#  '야식',
#  '금지',
#  '정',
#  '아메리카노',
#  '차',
#  '지방',
#  '우유',
#  '블루베리',
#  '딸기',
#  '채소',
#  '중',
#  '하나로',
#  '대체',
#  '물',
#  '중간',
#  '중간',
#  '마시기',
#  '물',
#  '매일',
#  '최소',
#  '리터',
#  '최대',
#  '리터',
#  '함',
#  '나',
#  '경우',
#  '리터',
#  '줌',
#  '과제',
#  '입',
#  '빵',
#  '저',
#  '지금',
#  '안성탕면',
#  '깜놀',
#  '청첩장',
#  '인사',
#  '매일',
#  '약속',
#  '살이',
#  '저절로',
#  '개',
#  '티',
#  '답변',
#  '운동',
#  '진짜',
#  '안',
#  '사람',
#  '체력',
#  '조깅',
#  '추천',
#  '건강',
#  '때',
#  '운동',
#  '체력',
#  '때',
#  '함',
#  '침대',
#  '거리',
#  '체중',
#  '앞컷',
#  '실제',
#  '말',
#  '장염',
#  '다이어트',
#  '현',
#  '고',
#  '때',
#  '코로나',
#  '시작',
#  '때',
#  '가족',
#  '식단',
#  '다시',
#  '여름',
#  '대면',
#  '헬스장',
#  '현재',
#  '다시',
#  '발목',
#  '원래',
#  '발목',
#  '점점',
#  '강의',
#  '생활',
#  '체육',
#  '도',
#  '운동',
#  '생활관',
#  '사',
#  '학교',
#  '체',
#  '운동',
#  '예정',
#  '고',
#  '이',
#  '몸무게',
#  '적업',
#  '슴',
#  '특정',
#  '부위',
#  '운동',
#  '림프절',
#  '폼',
#  '롤러',
#  '조지',
#  '분',
#  '림프절',
#  '지방',
#  '관련',
#  '아예',
#  '가슴',
#  '각오',
#  '유',
#  '산소',
#  '하루',
#  '지방',
#  '흡입',
#  '제일',
#  '달',
#  '동안',
#  '빼봄',
#  '운동',
#  '시세',
#  '끼',
#  '클린',
#  '염',
#  '집밥',
#  '기여',
#  '워',
#  '스튜디오',
#  '촬영',
#  '본식',
#  '촬영',
#  '뽀샵',
#  '정말',
#  '각오',
#  '본식',
#  '때',
#  '실제',
#  '본식',
#  '달',
#  '충격',
#  '요법',
#  '한가지',
#  '방법',
#  '팔',
#  '옆구리',
#  '살짝',
#  '덜',
#  '진짜',
#  '뭐',
#  '사람',
#  '스파',
#  '지방',
#  '흡입',
#  '등',
#  '재섭',
#  '다이어트',
#  '몸',
#  '가능',
#  '개월',
#  '유지',
#  '터',
#  '때',
#  '당뇨',
#  '초기',
#  '혈압',
#  '통풍',
#  '족',
#  '근막',
#  '등등',
#  '만신창이',
#  '병원',
#  '사형',
#  '직전',
#  '선고',
#  '입',
#  '몸',
#  '만화',
#  '오',
#  '케',
#  '결혼식',
#  '신랑',
#  '몸무',
#  '신부',
#  '진짜',
#  '땐',
#  '면사포',
#  '최고',
#  '방어',
#  '템',
#  '달동',
#  '안',
#  '토마토',
#  '닭',
#  '가슴',
#  '산만',
#  '금보',
#  '어케',
#  '바',
#  '탑제',
#  '체중',
#  '욕함',
#  '말',
#  '피부관리',
#  '하나',
#  '본식',
#  '달전',
#  '팔뚝',
#  '조지',
#  '주사',
#  '효과',
#  '개쩔',
#  '제로',
#  '콜라',
#  '탄산수',
#  '탄산수',
#  '물',
#  '중',
#  '탄산',
#  '전',
#  '늘',
#  '개월치',
#  '욥',
#  '장기간',
#  '내',
#  '자꾸',
#  '저',
#  '그냥',
#  '통통',
#  '한편',
#  '의지',
#  '편도',
#  '진짜',
#  '키',
#  '리하',
#  '굳이',
#  '마음',
#  '더',
#  '이제',
#  '결혼',
#  '쯤',
#  '다시',
#  '최고',
#  '네',
#  '집밥',
#  '최고',
#  '너',
#  '발',
#  '여러분',
#  '제로',
#  '콜라',
#  '비건',
#  '콜라',
#  '이',
#  '순수',
#  '칼로리',
#  '결혼',
#  '달전',
#  '단식',
#  '기숙',
#  '학원',
#  '재수',
#  '때',
#  '년',
#  '동안',
#  '스트레스',
#  '근육',
#  '살이',
#  '보기',
#  '팔뚝',
#  '똥',
#  '수능',
#  '후',
#  '운동',
#  '다시',
#  '몸',
#  '관리',
#  '다이어트',
#  '부위',
#  '별로',
#  '운동',
#  '컷',
#  '요',
#  '도',
#  '저',
#  '점심시간',
#  '더',
#  '그',
#  '시간',
#  '안',
#  '밥',
#  '바로',
#  '보',
#  '살이',
#  '수',
#  '왜',
#  '저',
#  '밥',
#  '산책',
#  '시간',
#  '포기',
#  '신부',
#  '입장',
#  '사람',
#  '여기',
#  '발',
#  '시간',
#  '줄',
#  '시간',
#  '사용',
#  '뜻',
#  '탄수화물',
#  '무시',
#  '근육',
#  '절때',
#  '안늠',
#  '어우',
#  '질량',
#  '보존',
#  '법칙',
#  '전',
#  '다이어트',
#  '포기',
#  '신부',
#  '등',
#  '허리',
#  '일반',
#  '남자',
#  '기초',
#  '사량',
#  '더',
#  '여자',
#  '쪽',
#  '더',
#  '제로',
#  '콜라',
#  '이야기',
#  '왜',
#  '작가',
#  '콜라',
#  '한적',
#  '헬스인',
#  '일단',
#  '재미',
#  '추천',
#  '그게',
#  '제일',
#  '빡셈',
#  '여러분',
#  '무엇',
#  '물',
#  '마셧는',
#  '드셧는',
#  '생각',
#  '거',
#  '저희',
#  '이야기',
#  '저희',
#  '앞',
#  '그',
#  '우리',
#  '뇌',
#  '포도당',
#  '에너지',
#  '사용',
#  '단백질',
#  '머리',
#  '대장',
#  '내시경',
#  '진짜',
#  '최고',
#  '피티쌤',
#  '식단',
#  '운동',
#  '빋으',
#  '절대',
#  '번',
#  '의지',
#  '양념',
#  '안',
#  '닭',
#  '가슴',
#  '살',
#  '두부',
#  '일주일',
#  '먹음',
#  '저',
#  '진돌',
#  '실연',
#  '다이어트',
#  '영상',
#  '약',
#  '뿔',
#  '아웃',
#  '풋후',
#  '인풋',
#  '진실',
#  '내',
#  '스밥',
#  '몇',
#  '개월',
#  '뒤',
#  '나',
#  '키로',
#  '도로',
#  '찜',
#  '배댓',
#  '저',
#  '결혼식',
#  '청첩장',
#  '다',
#  '식사',
#  '자리',
#  '오히려',
#  '더',
#  '마지막',
#  '바나나',
#  '개',
#  '식장',
#  '저',
#  '결혼',
#  '포켓몬',
#  '고',
#  '포켓몬',
#  '하루',
#  '기본',
#  '결혼식',
#  '달동',
#  '안',
#  '포켓몬',
#  '고의',
#  '힘',
#  '공감',
#  '저',
#  '결혼',
#  '때',
#  '인생',
#  '최대',
#  '몸무게',
#  '영혼',
#  '눈',
#  '꼭',
#  '거울',
#  '묵음',
#  '말',
#  '저',
#  '정싱체중',
#  '보고',
#  '어이',
#  '다이어트',
#  '시작',
#  '개월',
#  '과',
#  '를',
#  '대충',
#  '조금',
#  '줄',
#  '주말',
#  '자전거',
#  '만',
#  '다이어트',
#  '분',
#  '화이팅',
#  '저건',
#  '운동',
#  '재활',
#  '치료',
#  '앞',
#  '두',
#  '번',
#  '지금',
#  '내',
#  '모습',
#  '다이어트',
#  '과자',
#  '거',
#  '애',
#  '면역',
#  '약화',
#  '알러지',
#  '팔뚝',
#  '살',
#  '괄사',
#  '폼',
#  '롤러',
#  '혈액',
#  '순환',
#  '어깨',
#  '시작',
#  '자까님',
#  '입',
#  '발',
#  '저',
#  '후회',
#  '박명수',
#  '치킨',
#  ...]

# %%
# 불용어를 정의하고 제거한다.
stop_words = ['자까님', '정도', '본식', '다시', '우리', '때문']
review_tokens = [word for word in review_tokens if word not in stop_words]
# 단어가 1음절로 구성된 단어는 제거한다.
review_tokens = [word for word in review_tokens if len(word) > 1]
review_tokens
# Out:
# ['비상',
#  '주식',
#  '고생',
#  '고생',
#  '스트레스',
#  '남편',
#  '개월',
#  '한번',
#  '안감',
#  '야식',
#  '라면',
#  '간식',
#  '공기',
#  '삼시',
#  '꼬박꼬박',
#  '지금',
#  '가끔',
#  '거도',
#  '삼시',
#  '꼬박',
#  '유지',
#  '노력',
#  '야식',
#  '평생',
#  '생각',
#  '또르르',
#  '내일',
#  '하자',
#  '생각',
#  '지름길',
#  '튀김',
#  '탄수화물',
#  '시경',
#  '현실',
#  '무엇',
#  '생각',
#  '신랑',
#  '신부',
#  '청첩장',
#  '진짜',
#  '사람',
#  '의지',
#  '운동',
#  '안해',
#  '저절로',
#  '다이어트',
#  '사람',
#  '표정',
#  '무엇',
#  '우선',
#  '과자',
#  '멸치',
#  '표정',
#  '엄마',
#  '예식',
#  '당일',
#  '엄빠',
#  '덕분',
#  '식장',
#  '직도',
#  '층애',
#  '햄버거',
#  '햄버거',
#  '세트',
#  '결혼식',
#  '그날',
#  '임신',
#  '결혼',
#  '후문',
#  '햄버거',
#  '핑계',
#  '다행',
#  '원래',
#  '복부비만',
#  '팔다리',
#  '마루',
#  '잡고',
#  '결혼식',
#  '킬로',
#  '가량',
#  '뭐해',
#  '결혼',
#  '도로',
#  '지금',
#  '재수',
#  '시간',
#  '점저',
#  '시간',
#  '전부',
#  '부시',
#  '내내',
#  '먹기',
#  '시작',
#  '이지은',
#  '신지',
#  '다해',
#  '덤벨',
#  '중량',
#  '진짜',
#  '효과',
#  '직빵',
#  '투뿔',
#  '저희',
#  '아버지',
#  '지긍',
#  '다이어트',
#  '체중',
#  '샹크스',
#  '다이어트',
#  '법팔',
#  '몸무게',
#  '플로지스톤',
#  '다이어트',
#  '시구',
#  '최고',
#  '몸무게',
#  '지금',
#  '쭈그렁',
#  '이제',
#  '고정',
#  '프사',
#  '여기',
#  '시험',
#  '표정',
#  '요요',
#  '치킨',
#  '밀가루',
#  '결혼',
#  '개월',
#  '운동',
#  '손실',
#  '요요',
#  '요요',
#  '요지경',
#  '세상',
#  '지방',
#  '분해',
#  '주사',
#  '보톡스',
#  '결혼식',
#  '바로',
#  '전날',
#  '신랑',
#  '친구',
#  '호프',
#  '친척',
#  '벌써',
#  '한창',
#  '수능',
#  '공부',
#  '스트레스',
#  '기도',
#  '다이어트',
#  '공부',
#  '유지',
#  '진짜',
#  '절식',
#  '다이어트',
#  '연출',
#  '이건',
#  '한마디',
#  '진짜',
#  '결혼',
#  '모습',
#  '소름',
#  '개월',
#  '파인애플',
#  '요거트',
#  '최고',
#  '조합',
#  '산성',
#  '지방',
#  '분해',
#  '레몬',
#  '파인애플',
#  '과일',
#  '운동',
#  '내장',
#  '지방',
#  '빼주',
#  '요거트',
#  '조합',
#  '효과',
#  '땡볕',
#  '농구',
#  '금방',
#  '에어팟',
#  '현실',
#  '반영',
#  '제대로',
#  '뱃살',
#  '세상',
#  '사람인',
#  '일주일',
#  '매일',
#  '하루',
#  '미만',
#  '먹음',
#  '보기',
#  '유지',
#  '지금',
#  '최고',
#  '듯해',
#  '동생',
#  '미술',
#  '입시',
#  '대학',
#  '학년',
#  '과제',
#  '키로',
#  '읍니',
#  '대학가',
#  '커엽다',
#  '이후',
#  '몸무게',
#  '변화',
#  '대체로',
#  '유지',
#  '중이',
#  '중간',
#  '수가',
#  '절대',
#  '운동',
#  '처음',
#  '기초',
#  '체력',
#  '위해',
#  '걷기',
#  '산소',
#  '운동',
#  '시작',
#  '체력',
#  '차차',
#  '시작',
#  '차차',
#  '강도',
#  '서서히',
#  '워밍업',
#  '스트레칭',
#  '산소',
#  '운동',
#  '산소',
#  '운동',
#  '정적',
#  '스트레칭',
#  '해도',
#  '포기',
#  '며칠',
#  '산소',
#  '운동',
#  '강도',
#  '식이요법',
#  '병행',
#  '생리',
#  '증후군',
#  '습관',
#  '생리',
#  '기간',
#  '운동',
#  '요가',
#  '생리',
#  '불규칙',
#  '이면',
#  '운동',
#  '비상',
#  '사태',
#  '모드',
#  '지방',
#  '축적',
#  '결과',
#  '전보',
#  '살이',
#  '아침',
#  '자제',
#  '복부비만',
#  '원인',
#  '가까이',
#  '지금',
#  '유지',
#  '정체',
#  '날짜',
#  '자고',
#  '자기',
#  '금상첨화',
#  '저녁',
#  '먹기',
#  '일반',
#  '공기',
#  '공기',
#  '반찬',
#  '조금',
#  '국물',
#  '건더기',
#  '약간',
#  '함량',
#  '음식',
#  '음식',
#  '음식',
#  '먹기',
#  '치팅데이',
#  '경우',
#  '외식',
#  '경우',
#  '김밥',
#  '비빔밥',
#  '샐러드',
#  '샐러드',
#  '파스타',
#  '서브웨이',
#  '샌드위치',
#  '샤브샤브',
#  '소고기',
#  '야채',
#  '위주',
#  '쌀국수',
#  '비빔밥',
#  '추천',
#  '졸업',
#  '다이어트',
#  '시작',
#  '다이어트',
#  '생활',
#  '습관',
#  '평생',
#  '동안',
#  '지속',
#  '고려',
#  '식이요법',
#  '운동',
#  '병행',
#  '도비',
#  '경우',
#  '처음',
#  '운동',
#  '관절',
#  '식이요법',
#  '지방',
#  '바로',
#  '누우',
#  '식사',
#  '간식',
#  '야식',
#  '금지',
#  '아메리카노',
#  '지방',
#  '우유',
#  '블루베리',
#  '딸기',
#  '채소',
#  '하나로',
#  '대체',
#  '중간',
#  '중간',
#  '마시기',
#  '매일',
#  '최소',
#  '리터',
#  '최대',
#  '리터',
#  '경우',
#  '리터',
#  '과제',
#  '지금',
#  '안성탕면',
#  '깜놀',
#  '청첩장',
#  '인사',
#  '매일',
#  '약속',
#  '살이',
#  '저절로',
#  '답변',
#  '운동',
#  '진짜',
#  '사람',
#  '체력',
#  '조깅',
#  '추천',
#  '건강',
#  '운동',
#  '체력',
#  '침대',
#  '거리',
#  '체중',
#  '앞컷',
#  '실제',
#  '장염',
#  '다이어트',
#  '코로나',
#  '시작',
#  '가족',
#  '식단',
#  '여름',
#  '대면',
#  '헬스장',
#  '현재',
#  '발목',
#  '원래',
#  '발목',
#  '점점',
#  '강의',
#  '생활',
#  '체육',
#  '운동',
#  '생활관',
#  '학교',
#  '운동',
#  '예정',
#  '몸무게',
#  '적업',
#  '특정',
#  '부위',
#  '운동',
#  '림프절',
#  '롤러',
#  '조지',
#  '림프절',
#  '지방',
#  '관련',
#  '아예',
#  '가슴',
#  '각오',
#  '산소',
#  '하루',
#  '지방',
#  '흡입',
#  '제일',
#  '동안',
#  '빼봄',
#  '운동',
#  '시세',
#  '클린',
#  '집밥',
#  '기여',
#  '스튜디오',
#  '촬영',
#  '촬영',
#  '뽀샵',
#  '정말',
#  '각오',
#  '실제',
#  '충격',
#  '요법',
#  '한가지',
#  '방법',
#  '옆구리',
#  '살짝',
#  '진짜',
#  '사람',
#  '스파',
#  '지방',
#  '흡입',
#  '재섭',
#  '다이어트',
#  '가능',
#  '개월',
#  '유지',
#  '당뇨',
#  '초기',
#  '혈압',
#  '통풍',
#  '근막',
#  '등등',
#  '만신창이',
#  '병원',
#  '사형',
#  '직전',
#  '선고',
#  '만화',
#  '결혼식',
#  '신랑',
#  '몸무',
#  '신부',
#  '진짜',
#  '면사포',
#  '최고',
#  '방어',
#  '달동',
#  '토마토',
#  '가슴',
#  '산만',
#  '금보',
#  '어케',
#  '탑제',
#  '체중',
#  '욕함',
#  '피부관리',
#  '하나',
#  '달전',
#  '팔뚝',
#  '조지',
#  '주사',
#  '효과',
#  '개쩔',
#  '제로',
#  '콜라',
#  '탄산수',
#  '탄산수',
#  '탄산',
#  '개월치',
#  '장기간',
#  '자꾸',
#  '그냥',
#  '통통',
#  '한편',
#  '의지',
#  '편도',
#  '진짜',
#  '리하',
#  '굳이',
#  '마음',
#  '이제',
#  '결혼',
#  '최고',
#  '집밥',
#  '최고',
#  '여러분',
#  '제로',
#  '콜라',
#  '비건',
#  '콜라',
#  '순수',
#  '칼로리',
#  '결혼',
#  '달전',
#  '단식',
#  '기숙',
#  '학원',
#  '재수',
#  '동안',
#  '스트레스',
#  '근육',
#  '살이',
#  '보기',
#  '팔뚝',
#  '수능',
#  '운동',
#  '관리',
#  '다이어트',
#  '부위',
#  '별로',
#  '운동',
#  '점심시간',
#  '시간',
#  '바로',
#  '살이',
#  '산책',
#  '시간',
#  '포기',
#  '신부',
#  '입장',
#  '사람',
#  '여기',
#  '시간',
#  '시간',
#  '사용',
#  '탄수화물',
#  '무시',
#  '근육',
#  '절때',
#  '안늠',
#  '어우',
#  '질량',
#  '보존',
#  '법칙',
#  '다이어트',
#  '포기',
#  '신부',
#  '허리',
#  '일반',
#  '남자',
#  '기초',
#  '사량',
#  '여자',
#  '제로',
#  '콜라',
#  '이야기',
#  '작가',
#  '콜라',
#  '한적',
#  '헬스인',
#  '일단',
#  '재미',
#  '추천',
#  '그게',
#  '제일',
#  '빡셈',
#  '여러분',
#  '무엇',
#  '마셧는',
#  '드셧는',
#  '생각',
#  '저희',
#  '이야기',
#  '저희',
#  '포도당',
#  '에너지',
#  '사용',
#  '단백질',
#  '머리',
#  '대장',
#  '내시경',
#  '진짜',
#  '최고',
#  '피티쌤',
#  '식단',
#  '운동',
#  '빋으',
#  '절대',
#  '의지',
#  '양념',
#  '가슴',
#  '두부',
#  '일주일',
#  '먹음',
#  '진돌',
#  '실연',
#  '다이어트',
#  '영상',
#  '아웃',
#  '풋후',
#  '인풋',
#  '진실',
#  '스밥',
#  '개월',
#  '키로',
#  '도로',
#  '배댓',
#  '결혼식',
#  '청첩장',
#  '식사',
#  '자리',
#  '오히려',
#  '마지막',
#  '바나나',
#  '식장',
#  '결혼',
#  '포켓몬',
#  '포켓몬',
#  '하루',
#  '기본',
#  '결혼식',
#  '달동',
#  '포켓몬',
#  '고의',
#  '공감',
#  '결혼',
#  '인생',
#  '최대',
#  '몸무게',
#  '영혼',
#  '거울',
#  '묵음',
#  '정싱체중',
#  '보고',
#  '어이',
#  '다이어트',
#  '시작',
#  '개월',
#  '대충',
#  '조금',
#  '주말',
#  '자전거',
#  '다이어트',
#  '화이팅',
#  '저건',
#  '운동',
#  '재활',
#  '치료',
#  '지금',
#  '모습',
#  '다이어트',
#  '과자',
#  '면역',
#  '약화',
#  '알러지',
#  '팔뚝',
#  '괄사',
#  '롤러',
#  '혈액',
#  '순환',
#  '어깨',
#  '시작',
#  '후회',
#  '박명수',
#  '치킨',
#  '다이어트',
#  '야식',
#  '굽네치킨',
#  '로스트',
#  '기구',
#  '통닭',
#  '가능',
#  '캡쳐',
#  '이후',
#  '조절',
#  '유지',
#  '중임',
#  '허리',
#  '디스크',
#  '시작',
#  '바지',
#  '사이',
#  '숫자',
#  '바디',
#  '인바디',
#  '최고',
#  '란걸',
#  '느낌',
#  '진짜',
#  '라면',
#  '등등',
#  '대신',
#  '야채',
#  '식욕',
#  '그대로',
#  '나중',
#  '스스로',
#  '인지부조화',
#  '댓글',
#  '구라',
#  '일기',
#  '유콘',
#  '남편',
#  '순식간',
#  '시간',
#  '회복',
#  '남펀',
#  '결혼식',
#  '바로',
#  '전날',
#  '치킨',
#  '다이어트',
#  '의지',
#  '올해',
#  '킬로',
#  '라면',
#  '떡볶이',
#  '복근',
#  '바프',
#  '대장',
#  '강제',
#  '다이어트',
#  '킬러',
#  '뱃살',
#  '합리화',
#  '결혼식',
#  '전전날',
#  '치킨',
#  '엇읍',
#  '커피',
#  '햄버거',
#  '과자',
#  '음료',
#  '역대',
#  '몸무게',
#  '비만',
#  '결혼',
#  '한번',
#  '다이어트',
#  '사람',
#  '다이어트',
#  '제일',
#  '생각',
#  '생각',
#  '오히려',
#  '마음',
#  '예식',
#  '회장',
#  '신부',
#  '신랑',
#  '인사',
#  '보통',
#  '무슨',
#  '이야기',
#  '하나요',
#  '맥주',
#  '극혐',
#  '헬스장',
#  '기부',
#  '매달',
#  '동물보호',
#  '정기',
#  '후원',
#  '비만',
#  '보통',
#  '아주',
#  '차이',
#  '살집',
#  '뱃살',
#  '사랑',
#  '그냥',
#  '체형',
#  '안변',
#  '부위',
#  '얼굴',
#  '콧대',
#  '마사지',
#  '찰흙',
#  '마냥',
#  '인위',
#  '시술',
#  '안변',
#  '드레스',
#  '디자인',
#  '도태',
#  '페미',
#  '능력',
#  '노력',
#  '애인',
#  '이해',
#  '페미',
#  '신규',
#  '간호사',
#  '대학병원',
#  '가면',
#  '지금',
#  '퇴근',
#  '낮술',
#  '제법',
#  '글러',
#  '치킨',
#  '합의',
#  '기엽다',
#  '생각',
#  '식욕',
#  '허리',
#  '재활',
#  '피티',
#  '결혼',
#  '계란',
#  '가슴',
#  '과일',
#  '방토',
#  '바나나',
#  '결혼',
#  '개월',
#  '원상',
#  '복구',
#  '행복',
#  '다이어트',
#  '유지',
#  '요트',
#  '성공',
#  '인생',
#  '승리',
#  '월동',
#  '몸무게',
#  '목적',
#  '일단',
#  '요트',
#  '모든',
#  '화이팅',
#  '실천',
#  '의지',
#  '박약',
#  '가장',
#  '밀가루',
#  '하루',
#  '감량',
#  '공기',
#  '다이어트',
#  '키로',
#  '동안',
#  '그냥',
#  '단식',
#  '헬스',
#  '신지',
#  '로만',
#  '결혼',
#  '허벅지',
#  '안쪽',
#  '팔뚝',
#  '뱃살',
#  '지옥',
#  '버전',
#  '진짜',
#  '직빵',
#  '추천',
#  '사진',
#  '체중',
#  '진짜',
#  '지난번',
#  '드레스',
#  '선택',
#  '보고',
#  '등신대',
#  '사이즈',
#  '캐릭터',
#  '현실',
#  '드레스',
#  '드레스',
#  '제발',
#  '나발',
#  '단지',
#  '정답',
#  '크리스마스',
#  '이나',
#  '솔로',
#  '달이',
#  '최고',
#  '조금',
#  '가격',
#  '귀신',
#  '대학교',
#  '입학',
#  '저녁',
#  '운동',
#  '입학',
#  '살찐',
#  '무기',
#  '왜냐면',
#  '최선',
#  '다해',
#  '유지',
#  '무리',
#  '정상',
#  '방법',
#  '절대',
#  '유지',
#  '세월',
#  '체중',
#  '해도',
#  '직장',
#  '검사',
#  '기초',
#  '사량',
#  '서울대',
#  '의대',
#  '가나',
#  '나이',
#  '대면',
#  '병원',
#  '라면',
#  '입시',
#  '학원',
#  '저녁',
#  '단백질',
#  '먹기',
#  '식단',
#  '운동',
#  '진짜',
#  '식단',
#  '드레스',
#  '처음',
#  '투성이',
#  '인생',
#  '가족',
#  '사랑',
#  '사람',
#  '사람',
#  '다이어트',
#  '생각',
#  '개월',
#  '가지',
#  '전날',
#  '삼겹살',
#  '새벽',
#  '웨딩드레스',
#  '한번',
#  '권유',
#  '계속',
#  '봤어욬',
#  '현대',
#  '의학',
#  '기술',
#  '최고',
#  '결혼식',
#  '역시',
#  '주사',
#  '지방',
#  '흡입',
#  '대로',
#  '내일',
#  '모레',
#  '야외',
#  '촬영',
#  '치킨',
#  '중이',
#  '호호',
#  '다이어트',
#  '새삼',
#  '대장',
#  '내시경',
#  '경제활동',
#  '결혼식',
#  '준비',
#  '진짜',
#  '기력',
#  '회사',
#  '눈치',
#  '보이',
#  '평소',
#  '살이',
#  '걱정',
#  '결혼식',
#  '지나',
#  '헬스장',
#  '체중',
#  '세자',
#  ...]

# %%
# 워드 클라우드로 구현할 단어들의 출현 빈도수를 센다.
token = nltk.Text(review_tokens)
token.vocab().most_common(50)
# Out:
# [('다이어트', 186),
#  ('운동', 152),
#  ('진짜', 91),
#  ('사람', 82),
#  ('결혼', 67),
#  ('결혼식', 60),
#  ('생각', 56),
#  ('팔뚝', 55),
#  ('지금', 49),
#  ('지방', 47),
#  ('살이', 46),
#  ('드레스', 46),
#  ('유지', 44),
#  ('몸무게', 44),
#  ('치킨', 41),
#  ('개월', 38),
#  ('제로', 35),
#  ('체중', 33),
#  ('하루', 32),
#  ('그냥', 30),
#  ('식단', 29),
#  ('내시경', 27),
#  ('사진', 27),
#  ('탄수화물', 26),
#  ('가슴', 26),
#  ('근육', 26),
#  ('방법', 25),
#  ('신부', 24),
#  ('헬스장', 24),
#  ('대장', 24),
#  ('최고', 23),
#  ('감량', 23),
#  ('한번', 22),
#  ('정말', 22),
#  ('요요', 21),
#  ('남편', 20),
#  ('저녁', 20),
#  ('음식', 20),
#  ('작가', 20),
#  ('시작', 19),
#  ('이제', 19),
#  ('산소', 19),
#  ('동안', 19),
#  ('제일', 19),
#  ('콜라', 19),
#  ('단백질', 19),
#  ('포토샵', 19),
#  ('모습', 18),
#  ('처음', 18),
#  ('하나', 18)]

# %%
# 워드 클라우드로 구현할 단어를 뽑아내서 단어를 key로 하고 출현 빈도수를 value로 하는 딕셔너리를 만든다.
data = dict(token.vocab().most_common(200))

# %%
# 워드 클라우드 마스크 이미지
mask = np.array(Image.open('./images/mask.png'))

# %%
# 딕셔너리에 저장된 데이터를 generate_from_frequencies() 메소드를 사용해서 워드 클라우드를 만든다.
wordcloud = WordCloud(
    max_words=250,
    max_font_size=250,
    font_path='C:\\Windows\\Fonts\\NanumGothicCoding.ttf',
    background_color='white',
    mask=mask
).generate_from_frequencies(data)
plt.figure(figsize=(15, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
